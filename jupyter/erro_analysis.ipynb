# %%
from src.err_analysis import *
plt.style.use('properties.mplstyle')

# %%
if __name__ == "__main__":
    
    arquivo_selecionado = select_file()
    if arquivo_selecionado:
        mcs_values, erroJ_values, erroh_values = load_data(arquivo_selecionado)
        plotting_graphs2(mcs_values, erroJ_values, erroh_values, arquivo_selecionado)
        
    else:
        print("Nenhum arquivo foi selecionado.")
# Out:
# data_min_h = 7.01e-03,data_min_j = 6.32e-03, t_eq = 300, relx =  2

# %%
p = pd.read_csv("time_method_5", sep=' ')
aux = [i for i in range(1,len(p)+1)]
time, acc = p["time(s)"], p["swap_accept_rate"]
plt.plot(aux, acc)
plt.xlabel("MCS")
plt.ylabel("swap_accept")
plt.show()
