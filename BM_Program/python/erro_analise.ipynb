# %%
from src.err_analises import *

# %%
if __name__ == "__main__":
    arquivo_selecionado = select_file()
    if arquivo_selecionado:
        mcs_values, erroJ_values, erroh_values = load_data(arquivo_selecionado)
        plotting_graphs(mcs_values, erroJ_values, erroh_values, arquivo_selecionado)
    else:
        print("Nenhum arquivo foi selecionado.")
# Out:
# data_min_h = 1.52e-03,data_min_j = 1.17e-03

# %%
exact = True
if(exact == True):
    dir_results = "../Results/Comparative/"
else:
    dir_results = "../Results_Metropolis/Comparative/"

folders = ['correlation', 'magnetization','sisj','sisjsk','triplet']
filename = [dir_results + folders[i] for i in range(len(folders))]
filename
# list all folders in dir_results
# folders = [x[0] for x in os.walk(dir_results)]

# prop_name = []

# # Select all folder_names
# i = 0

# for folder in folders:
#     if(i>=1):
#         prop = os.path.basename(folder)
#         prop_name.append(prop)
#     else:
#         pass
#     i += 1
# Out:
# ['../Results/Comparative/correlation',
#  '../Results/Comparative/magnetization',
#  '../Results/Comparative/sisj',
#  '../Results/Comparative/sisjsk',
#  '../Results/Comparative/triplet']
