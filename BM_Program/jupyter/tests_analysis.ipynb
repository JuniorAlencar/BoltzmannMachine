# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../tests/metropolis/erros_j_min_2.00e-05_h_min_2.00e-05_mteq_150_mrelx_2.dat", sep=' ')
#df = pd.read_csv("../tests/exact/erros_j_min_2.00e-05_h_min_2.00e-05_mteq_150_mrelx_2.dat", sep=' ')
inter, errJ, errh = df["inter"], df["erroJ"], df["erroh"]
plt.plot(inter, errh,'-')
plt.yscale("log")
plt.show()
