# %%
from src.comp_analises import *

# %%
if __name__ == "__main__":
    arquivo_selecionado = select_file()
    if arquivo_selecionado:
        props, all_data = load_data(arquivo_selecionado)
        plotting_graphs(props, all_data)
    else:
        print("Nenhum arquivo foi selecionado.")
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[18], line 4
#       2 arquivo_selecionado = select_file()
#       3 if arquivo_selecionado:
# ----> 4     props, all_data = load_data(arquivo_selecionado)
#       5     plotting_graphs(props, all_data)
#       6 else:
#
# File ~/Documents/BoltzmannMachine/BM_Program/jupyter/src/comp_analises.py:69, in load_data(file)
#      67 # run all properties file, saving data in all_data dictionary
#      68 for i in range(len(filenames)):
# ---> 69     df = pd.read_csv(filenames[i], sep = ' ',header=None)
#      70     df.columns = ["exp", "ising"]
#      71     all_data[props[i]] = {"exp":df["exp"], "ising":df["ising"]}
#
# ...

# %%
import glob
prop = "triplet"
file = f"../Results_Metropolis/Comparative/{prop}/Tijk_exp_ising_sampleN20_err_j_9.92e-04_err_h_9.30e-04_mteq_300_mrelx_2.dat"
df = pd.read_csv(file, sep=' ',header=None)
df.columns = ["exp","ising"]

# %%
plt.plot(df["exp"],df["ising"],'o')
plt.plot(df["exp"],df["exp"])
plt.show()
