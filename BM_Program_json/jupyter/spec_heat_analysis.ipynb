# %%
from src.spec_heat_analysis import *

# %%
if __name__ == "__main__":
    arquivo_selecionado = select_file()
    if arquivo_selecionado:
        props, all_data = load_data_specific_heat(arquivo_selecionado)
        plotting_graphs_specific_heat(props, all_data)
    else:
        print("Nenhum arquivo foi selecionado.")
# Out:
# /home/junior/Documents/BoltzmannMachine/BM_Program/jupyter/src/spec_heat_analysis.py:76: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(prop={"size":30}, fancybox=True, framealpha=0.0)
